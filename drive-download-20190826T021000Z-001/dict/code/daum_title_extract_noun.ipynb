# %%
import pandas as pd
import soynlp
import string

# %%
# 데이터 읽기

file_path = 'daum_titles_0701_0710.csv'
corpus_path = 'daum_title_dic.csv'

df = pd.read_csv(file_path, encoding='utf-8')
df['Title'] = df['Title'].dropna().apply(lambda x:''.join([i for i in x 
                                                  if i not in string.punctuation]))
df.to_csv(corpus_path, encoding='utf-8', index=False)

# %%
df.head()
# Out:
#                                   Title
# 0            "팔짱 낀 김정숙 여사 외교 결례"? 진실은..
# 1                     독이 된 황교안의 '가벼운 입'
# 2                  밀착 보좌' 현송월..지켜보는 김여정
# 3        합참 "중부전선 DMZ서 레이더에 정체불명 항적 포착"
# 4  '김영철 후임' 北장금철, 판문점회동 참석한 듯..남측에 '첫선'

# %%
pd.read_csv(corpus_path, encoding='utf-8').head()
# Out:
#                            Title
# 0          팔짱 낀 김정숙 여사 외교 결례 진실은
# 1                독이 된 황교안의 가벼운 입
# 2              밀착 보좌 현송월지켜보는 김여정
# 3   합참 중부전선 DMZ서 레이더에 정체불명 항적 포착
# 4  김영철 후임 北장금철 판문점회동 참석한 듯남측에 첫선

# %%
from soynlp.utils import DoublespaceLineCorpus
from soynlp.noun import LRNounExtractor_v2

sents = DoublespaceLineCorpus(corpus_path, iter_sent=True)

# %%
noun_extractor = LRNounExtractor_v2(verbose=True, extract_compound=True)
noun_extractor.train(sents)
nouns = noun_extractor.train_extract(sents, min_noun_frequency=1,
                                     min_noun_score=0.3)
# Out:
# [Noun Extractor] use default predictors
# [Noun Extractor] num features: pos=1260, neg=1173, common=12
# [Noun Extractor] counting eojeols
# [EojeolCounter] n eojeol = 1544 from 301 sents. mem=0.125 Gb
# [Noun Extractor] complete eojeol counter -> lr graph
# [Noun Extractor] has been trained. #eojeols=2173, mem=0.128 Gb
# [Noun Extractor] counting eojeols
# [EojeolCounter] n eojeol = 1544 from 301 sents. mem=0.128 Gb
# [Noun Extractor] complete eojeol counter -> lr graph
# [Noun Extractor] has been trained. #eojeols=2173, mem=0.130 Gb
# [Noun Extractor] batch prediction was completed for 392 words
# [Noun Extractor] checked compounds. discovered 7 compounds
# [Noun Extractor] postprocessing detaching_features : 109 -> 109
# [Noun Extractor] postprocessing ignore_features : 109 -> 108
# [Noun Extractor] postprocessing ignore_NJ : 108 -> 108
# [Noun Extractor] 108 nouns (7 compounds) with min frequency=1
# [Noun Extractor] flushing was done. mem=0.130 Gb
# [Noun Extractor] 25.95 % eojeols are covered

# %%
a = [noun for noun, score in nouns.items() if len(noun) > 1]
a = [i.replace('"', '') for i in a] 
a = [i.replace("'", '') for i in a] 
len(a)
# Out:
# 82

# %%
a = pd.DataFrame(a, columns=['word'])
a['pos'] = 'NNP'
a = a[a['word'].str[-1] != '들']
a = a.drop_duplicates()
a
# Out:
#      word  pos
# 0   예결위원장  NNP
# 1   日수출규제  NNP
# 2   日경제보복  NNP
# 3    반일감정  NNP
# 4    수출규제  NNP
# 5    허심탄회  NNP
# 6    불매운동  NNP
# 7    경제보복  NNP
# 8    文대통령  NNP
# 9    무역전쟁  NNP
# 10   국회의원  NNP
# 11    나경원  NNP
# 12    윤대진  NNP
# 13    G20  NNP
# 14    황교안  NNP
# 15    WTO  NNP
# 16    김정은  NNP
# 17    정상회  NNP
# 18    광화문  NNP
# 19    윤우진  NNP
# 20    고민정  NNP
# 21    변호사  NNP
# 22    日정부  NNP
# 23    트럼프  NNP
# 24     대응  NNP
# 25     투신  NNP
# 26     상상  NNP
# 27     대표  NNP
# 28     악화  NNP
# 29     일본  NNP
# ..    ...  ...
# 52     아베  NNP
# 53     검사  NNP
# 54     꺼내  NNP
# 55     지적  NNP
# 56     조치  NNP
# 57     국익  NNP
# 58     하락  NNP
# 59     의혹  NNP
# 60     북한  NNP
# 61     논란  NNP
# 62     고려  NNP
# 63     비판  NNP
# 64     공세  NNP
# 65     MB  NNP
# 66     기사  NNP
# 67     요구  NNP
# 68     수입  NNP
# 69     약속  NNP
# 70     역할  NNP
# 71     제한  NNP
# 72     확산  NNP
# 73     전례  NNP
# 74     위증  NNP
# 75     임명  NNP
# 76     불매  NNP
# 77   보복조치  NNP
# 78   보복카드  NNP
# 79  논란윤대진  NNP
# 80   한국보복  NNP
# 81   대응일본  NNP
#
# [82 rows x 2 columns]

# %%
a.to_csv(corpus_path, encoding='utf-8', index=False, header=False)
